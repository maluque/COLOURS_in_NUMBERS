# %% [markdown]
# # DATA EXTRACTION
# # Scraping clothes from Amazon.es
#
#
# https://web.archive.org/web/20170701000000*/https://www.asos.com/es/mujer/

# %% [markdown]
# ### 0. Import modules

# %%
import pickle
import json

# %%
import pandas as pd
import time
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')


from selenium import webdriver
PATH = webdriver.FirefoxOptions() 


from selenium import webdriver
from selenium.webdriver.common.by import By
#from selenium.webdriver.support.ui import WebDriverWait   # para esperar a que cargue
#from selenium.webdriver.support import expected_conditions as EC   # condiciones esperadas


PATH = webdriver.FirefoxOptions()

# %% [markdown]
# ## 1. Use Selenium to scrap the data

# %% [markdown]
# ### 1.1  Open a Firefox window - driver

# %%
#driver.quit()
driver = webdriver.Firefox(options = PATH)
#driver.quit()

# %% [markdown]
# ### 1.2 Go to: `www.amazon.es`

# %%
url = 'https://www.amazon.es/'
driver.get(url)

# %% [markdown]
# ###  1.3 Accept cookies if asked

# %%
try:
    ## if amazon ask for cookies first
    try:
        driver.find_element(By.XPATH, '//*[@id="sp-cc-accept"]').click()

    ## if not, go directly to departments, there amazon will surely ask for cookies
    except:
        driver.find_element(By.XPATH, '/html/body/div/div[1]/div/div[1]/a[2]').click()
        time.sleep(3) # espera 2 segundos
        driver.find_element(By.XPATH, '/html/body/center/table/tbody/tr/td[2]/b[2]/a').click()
        ## cookies
        time.sleep(3) # espera 2 segundos
        driver.find_element(By.XPATH, '//*[@id="sp-cc-accept"]').click()
except:
    print("other new starting page")
# Out:
# other new starting page

# %% [markdown]
# ### 1.4 Navigate the web "by-clicking" to get `women t-shirts`
#
# Hamburguer button > ver todo > ropa > mujer > ropa > camiseta

# %%
driver.find_element(By.XPATH, '//*[@id="nav-hamburger-menu"]').click()
time.sleep(4) # espera 2 segundos
driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div/ul[1]/li[21]/a[1]').click()
time.sleep(4) # espera 2 segundos
driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div/ul[1]/ul[1]/li[7]/a').click()
time.sleep(4) # espera 2 segundos

# %% [markdown]
# Select the path you want, either men or women

# %%
men='/html/body/div[3]/div[2]/div/ul[44]/li[5]/a'
women='/html/body/div[3]/div[2]/div/ul[44]/li[4]/a'

driver.find_element(By.XPATH, men).click() ####
time.sleep(4) # espera 2 segundos

# %%
#clothes
driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div[2]/div/div/div[2]/ul/li[8]/span/a/span').click()
time.sleep(4) # espera 2 segundos
#tshirt
driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div[2]/div/div/div[2]/ul/li[6]/span/a/span').click()
time.sleep(4) # espera 2 segundos
#driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div[2]/div/div/div[2]/ul/li[6]/span/a/span').click()

# ver todos los resultados
driver.find_element(By.XPATH,'//*[@id="apb-desktop-browse-search-see-all"]').click()
time.sleep(4)

start_path=driver.current_url #save the url of the origin page before selecting colors

# %% [markdown]
# ### 1.5 Scrap all the content related to the products `by color` and  `by page`

# %% [markdown]
# * To move through the colors, I need to click the color, scrap and come back to the starting url. <br/>
#
# * To move along pages within each color, in need to pick a random number between 7-10.  <br/>
#
# * Once I get 20 pages for each of the 16 colors available (left-centered box), the loop ends and saves the data in a dictionary of lists.
#
# * Each time I scrap the data of a page, I need to parse it to text before moving to other urls.
#
# `sel_to_text` function parses selenium object to text and filters out irreleant elements (4 < len < 10)

# %%
def sel_to_text(selenium_list, min_=4, max_=10):
    text_list=[prod.text.split("\n") for prod in selenium_list] # selenium link to text
    text_list = [prod for prod in text_list if min_ < len(prod) < max_] # filter out irrelevant elements
    return text_list

# %% [markdown]
# **Don't run it**, super slow code. <br/>
# The same code **works for either men or women** clothes, just uncomment the code lines as necessary

# %%
driver.get(start_path)

color_index=range(1,16)

index_list=[7,8,9,10]*30

PAG_COLOR = 20 # define total pages for each color

products_pag_dict = {}

for c in color_index:

    driver.get(start_path)
    #men
    color_path=f'/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[9]/ul[4]/span[{str(c)}]/li/span/a'
    #women
    #color_path=f'/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[8]/ul[4]/span[{str(c)}]/li/span/a'
    test_col=driver.find_elements(By.XPATH, color_path)

    color_value=test_col[0].get_attribute("title")

    color_url=test_col[0].get_attribute("href") # url to the (next) color
    driver.get(color_url)

    print(f"Start with Color: {color_value}")
    time.sleep(5) # espera 5 segundos


    #### # each page of each color - FIRST PAGE
    count=1

    products_pag_list=[] 
    test0 = driver.find_elements(By.CLASS_NAME, 'sg-col-inner') # GET data FIRST PAGE
    #test0 = driver.find_elements(By.CLASS_NAME, 'a-section a-spacing-small puis-padding-left-micro puis-padding-right-micro') # GET data 
    TT=sel_to_text(test0)
    products_pag_list.append(TT) # FUN: append the relevant elements into the growing list

        #### # each page of each color - FOLLOWING PAGES
    for index in index_list: # try random "nth-child" indexes

        nextpag=f'a.s-pagination-item:nth-child({str(index)})'

        try: 
            driver.find_element(By.CSS_SELECTOR, nextpag).click()  #CHANGE page /within color X
            time.sleep(4) # espera 4 segundos
            try: 
                test0 = driver.find_elements(By.CLASS_NAME, 'sg-col-inner') # GET data FIRST PAGE
                TT=sel_to_text(test0)
                products_pag_list.append(TT) # FUN: append the relevant elements into the growing list

                time.sleep(2) # espera 2 segundos
                    #
                count += 1
                print("y", index)

            except:
                print("-", index)    
        except:
            print("n", index)
            #pass

        if count <= PAG_COLOR :
            print(f"Count: {count},  Continue {color_value}") #############

        else: # get info from 20 pages - STOP and GO to other color
            products_pag_dict[color_value] = products_pag_list # add the color list to a dict

            print("Color done")
            driver.get(start_path) # back to starting link to select a new color
            time.sleep(5) # espera 5 segundos
            break
            print("shouldn't be printed")

    print(f"Count: {count},  Next color")

print("All done!!")
# Out:
# Start with Color: Negro
# n 7
# Count: 1,  Continue Negro
# y 8
# Count: 2,  Continue Negro
# n 9
# Count: 2,  Continue Negro
# n 10
# Count: 2,  Continue Negro
# y 7
# Count: 3,  Continue Negro
# y 8
# Count: 4,  Continue Negro
# y 9
# Count: 5,  Continue Negro
# n 10
# Count: 5,  Continue Negro
# n 7
# Count: 5,  Continue Negro
# n 8
# Count: 5,  Continue Negro
# y 9
# Count: 6,  Continue Negro
# n 10
# Count: 6,  Continue Negro
# n 7
# Count: 6,  Continue Negro
# n 8
# Count: 6,  Continue Negro
# y 9
# Count: 7,  Continue Negro
# n 10
# Count: 7,  Continue Negro
# n 7
# Count: 7,  Continue Negro
# n 8
# Count: 7,  Continue Negro
# y 9
# Count: 8,  Continue Negro
# n 10
# Count: 8,  Continue Negro
# n 7
# Count: 8,  Continue Negro
# n 8
# Count: 8,  Continue Negro
# y 9
# Count: 9,  Continue Negro
# n 10
# Count: 9,  Continue Negro
# n 7
# Count: 9,  Continue Negro
# n 8
# Count: 9,  Continue Negro
# y 9
# Count: 10,  Continue Negro
# n 10
# Count: 10,  Continue Negro
# n 7
# Count: 10,  Continue Negro
# n 8
# Count: 10,  Continue Negro
# y 9
# Count: 11,  Continue Negro
# n 10
# Count: 11,  Continue Negro
# n 7
# Count: 11,  Continue Negro
# n 8
# Count: 11,  Continue Negro
# y 9
# Count: 12,  Continue Negro
# n 10
# Count: 12,  Continue Negro
# n 7
# Count: 12,  Continue Negro
# n 8
# Count: 12,  Continue Negro
# y 9
# Count: 13,  Continue Negro
# n 10
# Count: 13,  Continue Negro
# n 7
# Count: 13,  Continue Negro
# n 8
# Count: 13,  Continue Negro
# y 9
# Count: 14,  Continue Negro
# n 10
# Count: 14,  Continue Negro
# n 7
# Count: 14,  Continue Negro
# n 8
# Count: 14,  Continue Negro
# y 9
# Count: 15,  Continue Negro
# n 10
# Count: 15,  Continue Negro
# n 7
# Count: 15,  Continue Negro
# n 8
# Count: 15,  Continue Negro
# y 9
# Count: 16,  Continue Negro
# n 10
# Count: 16,  Continue Negro
# n 7
# Count: 16,  Continue Negro
# n 8
# Count: 16,  Continue Negro
# y 9
# Count: 17,  Continue Negro
# n 10
# Count: 17,  Continue Negro
# n 7
# Count: 17,  Continue Negro
# n 8
# Count: 17,  Continue Negro
# y 9
# Count: 18,  Continue Negro
# n 10
# Count: 18,  Continue Negro
# n 7
# Count: 18,  Continue Negro
# n 8
# Count: 18,  Continue Negro
# y 9
# Count: 19,  Continue Negro
# n 10
# Count: 19,  Continue Negro
# n 7
# Count: 19,  Continue Negro
# n 8
# Count: 19,  Continue Negro
# y 9
# Count: 20,  Continue Negro
# n 10
# Count: 20,  Continue Negro
# n 7
# Count: 20,  Continue Negro
# n 8
# Count: 20,  Continue Negro
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Gris
# n 7
# Count: 1,  Continue Gris
# y 8
# Count: 2,  Continue Gris
# n 9
# Count: 2,  Continue Gris
# n 10
# Count: 2,  Continue Gris
# y 7
# Count: 3,  Continue Gris
# y 8
# Count: 4,  Continue Gris
# y 9
# Count: 5,  Continue Gris
# n 10
# Count: 5,  Continue Gris
# n 7
# Count: 5,  Continue Gris
# n 8
# Count: 5,  Continue Gris
# y 9
# Count: 6,  Continue Gris
# n 10
# Count: 6,  Continue Gris
# n 7
# Count: 6,  Continue Gris
# n 8
# Count: 6,  Continue Gris
# y 9
# Count: 7,  Continue Gris
# n 10
# Count: 7,  Continue Gris
# n 7
# Count: 7,  Continue Gris
# n 8
# Count: 7,  Continue Gris
# y 9
# Count: 8,  Continue Gris
# n 10
# Count: 8,  Continue Gris
# n 7
# Count: 8,  Continue Gris
# n 8
# Count: 8,  Continue Gris
# y 9
# Count: 9,  Continue Gris
# n 10
# Count: 9,  Continue Gris
# n 7
# Count: 9,  Continue Gris
# n 8
# Count: 9,  Continue Gris
# y 9
# Count: 10,  Continue Gris
# n 10
# Count: 10,  Continue Gris
# n 7
# Count: 10,  Continue Gris
# n 8
# Count: 10,  Continue Gris
# y 9
# Count: 11,  Continue Gris
# n 10
# Count: 11,  Continue Gris
# n 7
# Count: 11,  Continue Gris
# n 8
# Count: 11,  Continue Gris
# y 9
# Count: 12,  Continue Gris
# n 10
# Count: 12,  Continue Gris
# n 7
# Count: 12,  Continue Gris
# n 8
# Count: 12,  Continue Gris
# y 9
# Count: 13,  Continue Gris
# n 10
# Count: 13,  Continue Gris
# n 7
# Count: 13,  Continue Gris
# n 8
# Count: 13,  Continue Gris
# y 9
# Count: 14,  Continue Gris
# n 10
# Count: 14,  Continue Gris
# n 7
# Count: 14,  Continue Gris
# n 8
# Count: 14,  Continue Gris
# y 9
# Count: 15,  Continue Gris
# n 10
# Count: 15,  Continue Gris
# n 7
# Count: 15,  Continue Gris
# n 8
# Count: 15,  Continue Gris
# y 9
# Count: 16,  Continue Gris
# n 10
# Count: 16,  Continue Gris
# n 7
# Count: 16,  Continue Gris
# n 8
# Count: 16,  Continue Gris
# y 9
# Count: 17,  Continue Gris
# n 10
# Count: 17,  Continue Gris
# n 7
# Count: 17,  Continue Gris
# n 8
# Count: 17,  Continue Gris
# y 9
# Count: 18,  Continue Gris
# n 10
# Count: 18,  Continue Gris
# n 7
# Count: 18,  Continue Gris
# n 8
# Count: 18,  Continue Gris
# y 9
# Count: 19,  Continue Gris
# n 10
# Count: 19,  Continue Gris
# n 7
# Count: 19,  Continue Gris
# n 8
# Count: 19,  Continue Gris
# y 9
# Count: 20,  Continue Gris
# n 10
# Count: 20,  Continue Gris
# n 7
# Count: 20,  Continue Gris
# n 8
# Count: 20,  Continue Gris
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Blanco
# n 7
# Count: 1,  Continue Blanco
# y 8
# Count: 2,  Continue Blanco
# n 9
# Count: 2,  Continue Blanco
# n 10
# Count: 2,  Continue Blanco
# y 7
# Count: 3,  Continue Blanco
# y 8
# Count: 4,  Continue Blanco
# y 9
# Count: 5,  Continue Blanco
# n 10
# Count: 5,  Continue Blanco
# n 7
# Count: 5,  Continue Blanco
# n 8
# Count: 5,  Continue Blanco
# y 9
# Count: 6,  Continue Blanco
# n 10
# Count: 6,  Continue Blanco
# n 7
# Count: 6,  Continue Blanco
# n 8
# Count: 6,  Continue Blanco
# y 9
# Count: 7,  Continue Blanco
# n 10
# Count: 7,  Continue Blanco
# n 7
# Count: 7,  Continue Blanco
# n 8
# Count: 7,  Continue Blanco
# y 9
# Count: 8,  Continue Blanco
# n 10
# Count: 8,  Continue Blanco
# n 7
# Count: 8,  Continue Blanco
# n 8
# Count: 8,  Continue Blanco
# y 9
# Count: 9,  Continue Blanco
# n 10
# Count: 9,  Continue Blanco
# n 7
# Count: 9,  Continue Blanco
# n 8
# Count: 9,  Continue Blanco
# y 9
# Count: 10,  Continue Blanco
# n 10
# Count: 10,  Continue Blanco
# n 7
# Count: 10,  Continue Blanco
# n 8
# Count: 10,  Continue Blanco
# y 9
# Count: 11,  Continue Blanco
# n 10
# Count: 11,  Continue Blanco
# n 7
# Count: 11,  Continue Blanco
# n 8
# Count: 11,  Continue Blanco
# y 9
# Count: 12,  Continue Blanco
# n 10
# Count: 12,  Continue Blanco
# n 7
# Count: 12,  Continue Blanco
# n 8
# Count: 12,  Continue Blanco
# y 9
# Count: 13,  Continue Blanco
# n 10
# Count: 13,  Continue Blanco
# n 7
# Count: 13,  Continue Blanco
# n 8
# Count: 13,  Continue Blanco
# y 9
# Count: 14,  Continue Blanco
# n 10
# Count: 14,  Continue Blanco
# n 7
# Count: 14,  Continue Blanco
# n 8
# Count: 14,  Continue Blanco
# y 9
# Count: 15,  Continue Blanco
# n 10
# Count: 15,  Continue Blanco
# n 7
# Count: 15,  Continue Blanco
# n 8
# Count: 15,  Continue Blanco
# y 9
# Count: 16,  Continue Blanco
# n 10
# Count: 16,  Continue Blanco
# n 7
# Count: 16,  Continue Blanco
# n 8
# Count: 16,  Continue Blanco
# y 9
# Count: 17,  Continue Blanco
# n 10
# Count: 17,  Continue Blanco
# n 7
# Count: 17,  Continue Blanco
# n 8
# Count: 17,  Continue Blanco
# y 9
# Count: 18,  Continue Blanco
# n 10
# Count: 18,  Continue Blanco
# n 7
# Count: 18,  Continue Blanco
# n 8
# Count: 18,  Continue Blanco
# y 9
# Count: 19,  Continue Blanco
# n 10
# Count: 19,  Continue Blanco
# n 7
# Count: 19,  Continue Blanco
# n 8
# Count: 19,  Continue Blanco
# y 9
# Count: 20,  Continue Blanco
# n 10
# Count: 20,  Continue Blanco
# n 7
# Count: 20,  Continue Blanco
# n 8
# Count: 20,  Continue Blanco
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Marrón
# n 7
# Count: 1,  Continue Marrón
# y 8
# Count: 2,  Continue Marrón
# n 9
# Count: 2,  Continue Marrón
# n 10
# Count: 2,  Continue Marrón
# y 7
# Count: 3,  Continue Marrón
# y 8
# Count: 4,  Continue Marrón
# y 9
# Count: 5,  Continue Marrón
# n 10
# Count: 5,  Continue Marrón
# n 7
# Count: 5,  Continue Marrón
# n 8
# Count: 5,  Continue Marrón
# y 9
# Count: 6,  Continue Marrón
# n 10
# Count: 6,  Continue Marrón
# n 7
# Count: 6,  Continue Marrón
# n 8
# Count: 6,  Continue Marrón
# y 9
# Count: 7,  Continue Marrón
# n 10
# Count: 7,  Continue Marrón
# n 7
# Count: 7,  Continue Marrón
# n 8
# Count: 7,  Continue Marrón
# y 9
# Count: 8,  Continue Marrón
# n 10
# Count: 8,  Continue Marrón
# n 7
# Count: 8,  Continue Marrón
# n 8
# Count: 8,  Continue Marrón
# y 9
# Count: 9,  Continue Marrón
# n 10
# Count: 9,  Continue Marrón
# n 7
# Count: 9,  Continue Marrón
# n 8
# Count: 9,  Continue Marrón
# y 9
# Count: 10,  Continue Marrón
# n 10
# Count: 10,  Continue Marrón
# n 7
# Count: 10,  Continue Marrón
# n 8
# Count: 10,  Continue Marrón
# y 9
# Count: 11,  Continue Marrón
# n 10
# Count: 11,  Continue Marrón
# n 7
# Count: 11,  Continue Marrón
# n 8
# Count: 11,  Continue Marrón
# y 9
# Count: 12,  Continue Marrón
# n 10
# Count: 12,  Continue Marrón
# n 7
# Count: 12,  Continue Marrón
# n 8
# Count: 12,  Continue Marrón
# y 9
# Count: 13,  Continue Marrón
# n 10
# Count: 13,  Continue Marrón
# n 7
# Count: 13,  Continue Marrón
# n 8
# Count: 13,  Continue Marrón
# y 9
# Count: 14,  Continue Marrón
# n 10
# Count: 14,  Continue Marrón
# n 7
# Count: 14,  Continue Marrón
# n 8
# Count: 14,  Continue Marrón
# y 9
# Count: 15,  Continue Marrón
# n 10
# Count: 15,  Continue Marrón
# n 7
# Count: 15,  Continue Marrón
# n 8
# Count: 15,  Continue Marrón
# y 9
# Count: 16,  Continue Marrón
# n 10
# Count: 16,  Continue Marrón
# n 7
# Count: 16,  Continue Marrón
# n 8
# Count: 16,  Continue Marrón
# y 9
# Count: 17,  Continue Marrón
# n 10
# Count: 17,  Continue Marrón
# n 7
# Count: 17,  Continue Marrón
# n 8
# Count: 17,  Continue Marrón
# y 9
# Count: 18,  Continue Marrón
# n 10
# Count: 18,  Continue Marrón
# n 7
# Count: 18,  Continue Marrón
# n 8
# Count: 18,  Continue Marrón
# y 9
# Count: 19,  Continue Marrón
# n 10
# Count: 19,  Continue Marrón
# n 7
# Count: 19,  Continue Marrón
# n 8
# Count: 19,  Continue Marrón
# y 9
# Count: 20,  Continue Marrón
# n 10
# Count: 20,  Continue Marrón
# n 7
# Count: 20,  Continue Marrón
# n 8
# Count: 20,  Continue Marrón
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Beis
# n 7
# Count: 1,  Continue Beis
# y 8
# Count: 2,  Continue Beis
# n 9
# Count: 2,  Continue Beis
# n 10
# Count: 2,  Continue Beis
# y 7
# Count: 3,  Continue Beis
# y 8
# Count: 4,  Continue Beis
# y 9
# Count: 5,  Continue Beis
# n 10
# Count: 5,  Continue Beis
# n 7
# Count: 5,  Continue Beis
# n 8
# Count: 5,  Continue Beis
# y 9
# Count: 6,  Continue Beis
# n 10
# Count: 6,  Continue Beis
# n 7
# Count: 6,  Continue Beis
# n 8
# Count: 6,  Continue Beis
# y 9
# Count: 7,  Continue Beis
# n 10
# Count: 7,  Continue Beis
# n 7
# Count: 7,  Continue Beis
# n 8
# Count: 7,  Continue Beis
# y 9
# Count: 8,  Continue Beis
# n 10
# Count: 8,  Continue Beis
# n 7
# Count: 8,  Continue Beis
# n 8
# Count: 8,  Continue Beis
# y 9
# Count: 9,  Continue Beis
# n 10
# Count: 9,  Continue Beis
# n 7
# Count: 9,  Continue Beis
# n 8
# Count: 9,  Continue Beis
# y 9
# Count: 10,  Continue Beis
# n 10
# Count: 10,  Continue Beis
# n 7
# Count: 10,  Continue Beis
# n 8
# Count: 10,  Continue Beis
# y 9
# Count: 11,  Continue Beis
# n 10
# Count: 11,  Continue Beis
# n 7
# Count: 11,  Continue Beis
# n 8
# Count: 11,  Continue Beis
# y 9
# Count: 12,  Continue Beis
# n 10
# Count: 12,  Continue Beis
# n 7
# Count: 12,  Continue Beis
# n 8
# Count: 12,  Continue Beis
# y 9
# Count: 13,  Continue Beis
# n 10
# Count: 13,  Continue Beis
# n 7
# Count: 13,  Continue Beis
# n 8
# Count: 13,  Continue Beis
# y 9
# Count: 14,  Continue Beis
# n 10
# Count: 14,  Continue Beis
# n 7
# Count: 14,  Continue Beis
# n 8
# Count: 14,  Continue Beis
# y 9
# Count: 15,  Continue Beis
# n 10
# Count: 15,  Continue Beis
# n 7
# Count: 15,  Continue Beis
# n 8
# Count: 15,  Continue Beis
# y 9
# Count: 16,  Continue Beis
# n 10
# Count: 16,  Continue Beis
# n 7
# Count: 16,  Continue Beis
# n 8
# Count: 16,  Continue Beis
# y 9
# Count: 17,  Continue Beis
# n 10
# Count: 17,  Continue Beis
# n 7
# Count: 17,  Continue Beis
# n 8
# Count: 17,  Continue Beis
# y 9
# Count: 18,  Continue Beis
# n 10
# Count: 18,  Continue Beis
# n 7
# Count: 18,  Continue Beis
# n 8
# Count: 18,  Continue Beis
# y 9
# Count: 19,  Continue Beis
# n 10
# Count: 19,  Continue Beis
# n 7
# Count: 19,  Continue Beis
# n 8
# Count: 19,  Continue Beis
# y 9
# Count: 20,  Continue Beis
# n 10
# Count: 20,  Continue Beis
# n 7
# Count: 20,  Continue Beis
# n 8
# Count: 20,  Continue Beis
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Rojo
# n 7
# Count: 1,  Continue Rojo
# y 8
# Count: 2,  Continue Rojo
# n 9
# Count: 2,  Continue Rojo
# n 10
# Count: 2,  Continue Rojo
# y 7
# Count: 3,  Continue Rojo
# y 8
# Count: 4,  Continue Rojo
# y 9
# Count: 5,  Continue Rojo
# n 10
# Count: 5,  Continue Rojo
# n 7
# Count: 5,  Continue Rojo
# n 8
# Count: 5,  Continue Rojo
# y 9
# Count: 6,  Continue Rojo
# n 10
# Count: 6,  Continue Rojo
# n 7
# Count: 6,  Continue Rojo
# n 8
# Count: 6,  Continue Rojo
# y 9
# Count: 7,  Continue Rojo
# n 10
# Count: 7,  Continue Rojo
# n 7
# Count: 7,  Continue Rojo
# n 8
# Count: 7,  Continue Rojo
# y 9
# Count: 8,  Continue Rojo
# n 10
# Count: 8,  Continue Rojo
# n 7
# Count: 8,  Continue Rojo
# n 8
# Count: 8,  Continue Rojo
# y 9
# Count: 9,  Continue Rojo
# n 10
# Count: 9,  Continue Rojo
# n 7
# Count: 9,  Continue Rojo
# n 8
# Count: 9,  Continue Rojo
# y 9
# Count: 10,  Continue Rojo
# n 10
# Count: 10,  Continue Rojo
# n 7
# Count: 10,  Continue Rojo
# n 8
# Count: 10,  Continue Rojo
# y 9
# Count: 11,  Continue Rojo
# n 10
# Count: 11,  Continue Rojo
# n 7
# Count: 11,  Continue Rojo
# n 8
# Count: 11,  Continue Rojo
# y 9
# Count: 12,  Continue Rojo
# n 10
# Count: 12,  Continue Rojo
# n 7
# Count: 12,  Continue Rojo
# n 8
# Count: 12,  Continue Rojo
# y 9
# Count: 13,  Continue Rojo
# n 10
# Count: 13,  Continue Rojo
# n 7
# Count: 13,  Continue Rojo
# n 8
# Count: 13,  Continue Rojo
# y 9
# Count: 14,  Continue Rojo
# n 10
# Count: 14,  Continue Rojo
# n 7
# Count: 14,  Continue Rojo
# n 8
# Count: 14,  Continue Rojo
# y 9
# Count: 15,  Continue Rojo
# n 10
# Count: 15,  Continue Rojo
# n 7
# Count: 15,  Continue Rojo
# n 8
# Count: 15,  Continue Rojo
# y 9
# Count: 16,  Continue Rojo
# n 10
# Count: 16,  Continue Rojo
# n 7
# Count: 16,  Continue Rojo
# n 8
# Count: 16,  Continue Rojo
# y 9
# Count: 17,  Continue Rojo
# n 10
# Count: 17,  Continue Rojo
# n 7
# Count: 17,  Continue Rojo
# n 8
# Count: 17,  Continue Rojo
# y 9
# Count: 18,  Continue Rojo
# n 10
# Count: 18,  Continue Rojo
# n 7
# Count: 18,  Continue Rojo
# n 8
# Count: 18,  Continue Rojo
# y 9
# Count: 19,  Continue Rojo
# n 10
# Count: 19,  Continue Rojo
# n 7
# Count: 19,  Continue Rojo
# n 8
# Count: 19,  Continue Rojo
# y 9
# Count: 20,  Continue Rojo
# n 10
# Count: 20,  Continue Rojo
# n 7
# Count: 20,  Continue Rojo
# n 8
# Count: 20,  Continue Rojo
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Rosa
# n 7
# Count: 1,  Continue Rosa
# y 8
# Count: 2,  Continue Rosa
# n 9
# Count: 2,  Continue Rosa
# n 10
# Count: 2,  Continue Rosa
# y 7
# Count: 3,  Continue Rosa
# y 8
# Count: 4,  Continue Rosa
# y 9
# Count: 5,  Continue Rosa
# n 10
# Count: 5,  Continue Rosa
# n 7
# Count: 5,  Continue Rosa
# n 8
# Count: 5,  Continue Rosa
# y 9
# Count: 6,  Continue Rosa
# n 10
# Count: 6,  Continue Rosa
# n 7
# Count: 6,  Continue Rosa
# n 8
# Count: 6,  Continue Rosa
# y 9
# Count: 7,  Continue Rosa
# n 10
# Count: 7,  Continue Rosa
# n 7
# Count: 7,  Continue Rosa
# n 8
# Count: 7,  Continue Rosa
# y 9
# Count: 8,  Continue Rosa
# n 10
# Count: 8,  Continue Rosa
# n 7
# Count: 8,  Continue Rosa
# n 8
# Count: 8,  Continue Rosa
# y 9
# Count: 9,  Continue Rosa
# n 10
# Count: 9,  Continue Rosa
# n 7
# Count: 9,  Continue Rosa
# n 8
# Count: 9,  Continue Rosa
# y 9
# Count: 10,  Continue Rosa
# n 10
# Count: 10,  Continue Rosa
# n 7
# Count: 10,  Continue Rosa
# n 8
# Count: 10,  Continue Rosa
# y 9
# Count: 11,  Continue Rosa
# n 10
# Count: 11,  Continue Rosa
# n 7
# Count: 11,  Continue Rosa
# n 8
# Count: 11,  Continue Rosa
# y 9
# Count: 12,  Continue Rosa
# n 10
# Count: 12,  Continue Rosa
# n 7
# Count: 12,  Continue Rosa
# n 8
# Count: 12,  Continue Rosa
# y 9
# Count: 13,  Continue Rosa
# n 10
# Count: 13,  Continue Rosa
# n 7
# Count: 13,  Continue Rosa
# n 8
# Count: 13,  Continue Rosa
# y 9
# Count: 14,  Continue Rosa
# n 10
# Count: 14,  Continue Rosa
# n 7
# Count: 14,  Continue Rosa
# n 8
# Count: 14,  Continue Rosa
# y 9
# Count: 15,  Continue Rosa
# n 10
# Count: 15,  Continue Rosa
# n 7
# Count: 15,  Continue Rosa
# n 8
# Count: 15,  Continue Rosa
# y 9
# Count: 16,  Continue Rosa
# n 10
# Count: 16,  Continue Rosa
# n 7
# Count: 16,  Continue Rosa
# n 8
# Count: 16,  Continue Rosa
# y 9
# Count: 17,  Continue Rosa
# n 10
# Count: 17,  Continue Rosa
# n 7
# Count: 17,  Continue Rosa
# n 8
# Count: 17,  Continue Rosa
# y 9
# Count: 18,  Continue Rosa
# n 10
# Count: 18,  Continue Rosa
# n 7
# Count: 18,  Continue Rosa
# n 8
# Count: 18,  Continue Rosa
# y 9
# Count: 19,  Continue Rosa
# n 10
# Count: 19,  Continue Rosa
# n 7
# Count: 19,  Continue Rosa
# n 8
# Count: 19,  Continue Rosa
# y 9
# Count: 20,  Continue Rosa
# n 10
# Count: 20,  Continue Rosa
# n 7
# Count: 20,  Continue Rosa
# n 8
# Count: 20,  Continue Rosa
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Naranja
# n 7
# Count: 1,  Continue Naranja
# y 8
# Count: 2,  Continue Naranja
# n 9
# Count: 2,  Continue Naranja
# n 10
# Count: 2,  Continue Naranja
# y 7
# Count: 3,  Continue Naranja
# y 8
# Count: 4,  Continue Naranja
# y 9
# Count: 5,  Continue Naranja
# n 10
# Count: 5,  Continue Naranja
# n 7
# Count: 5,  Continue Naranja
# n 8
# Count: 5,  Continue Naranja
# y 9
# Count: 6,  Continue Naranja
# n 10
# Count: 6,  Continue Naranja
# n 7
# Count: 6,  Continue Naranja
# n 8
# Count: 6,  Continue Naranja
# y 9
# Count: 7,  Continue Naranja
# n 10
# Count: 7,  Continue Naranja
# n 7
# Count: 7,  Continue Naranja
# n 8
# Count: 7,  Continue Naranja
# y 9
# Count: 8,  Continue Naranja
# n 10
# Count: 8,  Continue Naranja
# n 7
# Count: 8,  Continue Naranja
# n 8
# Count: 8,  Continue Naranja
# y 9
# Count: 9,  Continue Naranja
# n 10
# Count: 9,  Continue Naranja
# n 7
# Count: 9,  Continue Naranja
# n 8
# Count: 9,  Continue Naranja
# y 9
# Count: 10,  Continue Naranja
# n 10
# Count: 10,  Continue Naranja
# n 7
# Count: 10,  Continue Naranja
# n 8
# Count: 10,  Continue Naranja
# y 9
# Count: 11,  Continue Naranja
# n 10
# Count: 11,  Continue Naranja
# n 7
# Count: 11,  Continue Naranja
# n 8
# Count: 11,  Continue Naranja
# y 9
# Count: 12,  Continue Naranja
# n 10
# Count: 12,  Continue Naranja
# n 7
# Count: 12,  Continue Naranja
# n 8
# Count: 12,  Continue Naranja
# y 9
# Count: 13,  Continue Naranja
# n 10
# Count: 13,  Continue Naranja
# n 7
# Count: 13,  Continue Naranja
# n 8
# Count: 13,  Continue Naranja
# y 9
# Count: 14,  Continue Naranja
# n 10
# Count: 14,  Continue Naranja
# n 7
# Count: 14,  Continue Naranja
# n 8
# Count: 14,  Continue Naranja
# y 9
# Count: 15,  Continue Naranja
# n 10
# Count: 15,  Continue Naranja
# n 7
# Count: 15,  Continue Naranja
# n 8
# Count: 15,  Continue Naranja
# y 9
# Count: 16,  Continue Naranja
# n 10
# Count: 16,  Continue Naranja
# n 7
# Count: 16,  Continue Naranja
# n 8
# Count: 16,  Continue Naranja
# y 9
# Count: 17,  Continue Naranja
# n 10
# Count: 17,  Continue Naranja
# n 7
# Count: 17,  Continue Naranja
# n 8
# Count: 17,  Continue Naranja
# y 9
# Count: 18,  Continue Naranja
# n 10
# Count: 18,  Continue Naranja
# n 7
# Count: 18,  Continue Naranja
# n 8
# Count: 18,  Continue Naranja
# y 9
# Count: 19,  Continue Naranja
# n 10
# Count: 19,  Continue Naranja
# n 7
# Count: 19,  Continue Naranja
# n 8
# Count: 19,  Continue Naranja
# y 9
# Count: 20,  Continue Naranja
# n 10
# Count: 20,  Continue Naranja
# n 7
# Count: 20,  Continue Naranja
# n 8
# Count: 20,  Continue Naranja
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Amarillo
# n 7
# Count: 1,  Continue Amarillo
# y 8
# Count: 2,  Continue Amarillo
# n 9
# Count: 2,  Continue Amarillo
# n 10
# Count: 2,  Continue Amarillo
# y 7
# Count: 3,  Continue Amarillo
# y 8
# Count: 4,  Continue Amarillo
# y 9
# Count: 5,  Continue Amarillo
# n 10
# Count: 5,  Continue Amarillo
# n 7
# Count: 5,  Continue Amarillo
# n 8
# Count: 5,  Continue Amarillo
# y 9
# Count: 6,  Continue Amarillo
# n 10
# Count: 6,  Continue Amarillo
# n 7
# Count: 6,  Continue Amarillo
# n 8
# Count: 6,  Continue Amarillo
# y 9
# Count: 7,  Continue Amarillo
# n 10
# Count: 7,  Continue Amarillo
# n 7
# Count: 7,  Continue Amarillo
# n 8
# Count: 7,  Continue Amarillo
# y 9
# Count: 8,  Continue Amarillo
# n 10
# Count: 8,  Continue Amarillo
# n 7
# Count: 8,  Continue Amarillo
# n 8
# Count: 8,  Continue Amarillo
# y 9
# Count: 9,  Continue Amarillo
# n 10
# Count: 9,  Continue Amarillo
# n 7
# Count: 9,  Continue Amarillo
# n 8
# Count: 9,  Continue Amarillo
# y 9
# Count: 10,  Continue Amarillo
# n 10
# Count: 10,  Continue Amarillo
# n 7
# Count: 10,  Continue Amarillo
# n 8
# Count: 10,  Continue Amarillo
# y 9
# Count: 11,  Continue Amarillo
# n 10
# Count: 11,  Continue Amarillo
# n 7
# Count: 11,  Continue Amarillo
# n 8
# Count: 11,  Continue Amarillo
# y 9
# Count: 12,  Continue Amarillo
# n 10
# Count: 12,  Continue Amarillo
# n 7
# Count: 12,  Continue Amarillo
# n 8
# Count: 12,  Continue Amarillo
# y 9
# Count: 13,  Continue Amarillo
# n 10
# Count: 13,  Continue Amarillo
# n 7
# Count: 13,  Continue Amarillo
# n 8
# Count: 13,  Continue Amarillo
# y 9
# Count: 14,  Continue Amarillo
# n 10
# Count: 14,  Continue Amarillo
# n 7
# Count: 14,  Continue Amarillo
# n 8
# Count: 14,  Continue Amarillo
# y 9
# Count: 15,  Continue Amarillo
# n 10
# Count: 15,  Continue Amarillo
# n 7
# Count: 15,  Continue Amarillo
# n 8
# Count: 15,  Continue Amarillo
# y 9
# Count: 16,  Continue Amarillo
# n 10
# Count: 16,  Continue Amarillo
# n 7
# Count: 16,  Continue Amarillo
# n 8
# Count: 16,  Continue Amarillo
# y 9
# Count: 17,  Continue Amarillo
# n 10
# Count: 17,  Continue Amarillo
# n 7
# Count: 17,  Continue Amarillo
# n 8
# Count: 17,  Continue Amarillo
# y 9
# Count: 18,  Continue Amarillo
# n 10
# Count: 18,  Continue Amarillo
# n 7
# Count: 18,  Continue Amarillo
# n 8
# Count: 18,  Continue Amarillo
# y 9
# Count: 19,  Continue Amarillo
# n 10
# Count: 19,  Continue Amarillo
# n 7
# Count: 19,  Continue Amarillo
# n 8
# Count: 19,  Continue Amarillo
# y 9
# Count: 20,  Continue Amarillo
# n 10
# Count: 20,  Continue Amarillo
# n 7
# Count: 20,  Continue Amarillo
# n 8
# Count: 20,  Continue Amarillo
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Marfil
# n 7
# Count: 1,  Continue Marfil
# y 8
# Count: 2,  Continue Marfil
# n 9
# Count: 2,  Continue Marfil
# n 10
# Count: 2,  Continue Marfil
# y 7
# Count: 3,  Continue Marfil
# y 8
# Count: 4,  Continue Marfil
# y 9
# Count: 5,  Continue Marfil
# n 10
# Count: 5,  Continue Marfil
# n 7
# Count: 5,  Continue Marfil
# n 8
# Count: 5,  Continue Marfil
# y 9
# Count: 6,  Continue Marfil
# n 10
# Count: 6,  Continue Marfil
# n 7
# Count: 6,  Continue Marfil
# n 8
# Count: 6,  Continue Marfil
# y 9
# Count: 7,  Continue Marfil
# n 10
# Count: 7,  Continue Marfil
# n 7
# Count: 7,  Continue Marfil
# n 8
# Count: 7,  Continue Marfil
# y 9
# Count: 8,  Continue Marfil
# n 10
# Count: 8,  Continue Marfil
# n 7
# Count: 8,  Continue Marfil
# n 8
# Count: 8,  Continue Marfil
# y 9
# Count: 9,  Continue Marfil
# n 10
# Count: 9,  Continue Marfil
# n 7
# Count: 9,  Continue Marfil
# n 8
# Count: 9,  Continue Marfil
# y 9
# Count: 10,  Continue Marfil
# n 10
# Count: 10,  Continue Marfil
# n 7
# Count: 10,  Continue Marfil
# n 8
# Count: 10,  Continue Marfil
# y 9
# Count: 11,  Continue Marfil
# n 10
# Count: 11,  Continue Marfil
# n 7
# Count: 11,  Continue Marfil
# n 8
# Count: 11,  Continue Marfil
# y 9
# Count: 12,  Continue Marfil
# n 10
# Count: 12,  Continue Marfil
# n 7
# Count: 12,  Continue Marfil
# n 8
# Count: 12,  Continue Marfil
# y 9
# Count: 13,  Continue Marfil
# n 10
# Count: 13,  Continue Marfil
# n 7
# Count: 13,  Continue Marfil
# n 8
# Count: 13,  Continue Marfil
# y 9
# Count: 14,  Continue Marfil
# n 10
# Count: 14,  Continue Marfil
# n 7
# Count: 14,  Continue Marfil
# n 8
# Count: 14,  Continue Marfil
# y 9
# Count: 15,  Continue Marfil
# n 10
# Count: 15,  Continue Marfil
# n 7
# Count: 15,  Continue Marfil
# n 8
# Count: 15,  Continue Marfil
# y 9
# Count: 16,  Continue Marfil
# n 10
# Count: 16,  Continue Marfil
# n 7
# Count: 16,  Continue Marfil
# n 8
# Count: 16,  Continue Marfil
# y 9
# Count: 17,  Continue Marfil
# n 10
# Count: 17,  Continue Marfil
# n 7
# Count: 17,  Continue Marfil
# n 8
# Count: 17,  Continue Marfil
# y 9
# Count: 18,  Continue Marfil
# n 10
# Count: 18,  Continue Marfil
# n 7
# Count: 18,  Continue Marfil
# n 8
# Count: 18,  Continue Marfil
# y 9
# Count: 19,  Continue Marfil
# n 10
# Count: 19,  Continue Marfil
# n 7
# Count: 19,  Continue Marfil
# n 8
# Count: 19,  Continue Marfil
# y 9
# Count: 20,  Continue Marfil
# n 10
# Count: 20,  Continue Marfil
# n 7
# Count: 20,  Continue Marfil
# n 8
# Count: 20,  Continue Marfil
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Verde
# n 7
# Count: 1,  Continue Verde
# y 8
# Count: 2,  Continue Verde
# n 9
# Count: 2,  Continue Verde
# n 10
# Count: 2,  Continue Verde
# y 7
# Count: 3,  Continue Verde
# y 8
# Count: 4,  Continue Verde
# y 9
# Count: 5,  Continue Verde
# n 10
# Count: 5,  Continue Verde
# n 7
# Count: 5,  Continue Verde
# n 8
# Count: 5,  Continue Verde
# y 9
# Count: 6,  Continue Verde
# n 10
# Count: 6,  Continue Verde
# n 7
# Count: 6,  Continue Verde
# n 8
# Count: 6,  Continue Verde
# y 9
# Count: 7,  Continue Verde
# n 10
# Count: 7,  Continue Verde
# n 7
# Count: 7,  Continue Verde
# n 8
# Count: 7,  Continue Verde
# y 9
# Count: 8,  Continue Verde
# n 10
# Count: 8,  Continue Verde
# n 7
# Count: 8,  Continue Verde
# n 8
# Count: 8,  Continue Verde
# y 9
# Count: 9,  Continue Verde
# n 10
# Count: 9,  Continue Verde
# n 7
# Count: 9,  Continue Verde
# n 8
# Count: 9,  Continue Verde
# y 9
# Count: 10,  Continue Verde
# n 10
# Count: 10,  Continue Verde
# n 7
# Count: 10,  Continue Verde
# n 8
# Count: 10,  Continue Verde
# y 9
# Count: 11,  Continue Verde
# n 10
# Count: 11,  Continue Verde
# n 7
# Count: 11,  Continue Verde
# n 8
# Count: 11,  Continue Verde
# y 9
# Count: 12,  Continue Verde
# n 10
# Count: 12,  Continue Verde
# n 7
# Count: 12,  Continue Verde
# n 8
# Count: 12,  Continue Verde
# y 9
# Count: 13,  Continue Verde
# n 10
# Count: 13,  Continue Verde
# n 7
# Count: 13,  Continue Verde
# n 8
# Count: 13,  Continue Verde
# y 9
# Count: 14,  Continue Verde
# n 10
# Count: 14,  Continue Verde
# n 7
# Count: 14,  Continue Verde
# n 8
# Count: 14,  Continue Verde
# y 9
# Count: 15,  Continue Verde
# n 10
# Count: 15,  Continue Verde
# n 7
# Count: 15,  Continue Verde
# n 8
# Count: 15,  Continue Verde
# y 9
# Count: 16,  Continue Verde
# n 10
# Count: 16,  Continue Verde
# n 7
# Count: 16,  Continue Verde
# n 8
# Count: 16,  Continue Verde
# y 9
# Count: 17,  Continue Verde
# n 10
# Count: 17,  Continue Verde
# n 7
# Count: 17,  Continue Verde
# n 8
# Count: 17,  Continue Verde
# y 9
# Count: 18,  Continue Verde
# n 10
# Count: 18,  Continue Verde
# n 7
# Count: 18,  Continue Verde
# n 8
# Count: 18,  Continue Verde
# y 9
# Count: 19,  Continue Verde
# n 10
# Count: 19,  Continue Verde
# n 7
# Count: 19,  Continue Verde
# n 8
# Count: 19,  Continue Verde
# y 9
# Count: 20,  Continue Verde
# n 10
# Count: 20,  Continue Verde
# n 7
# Count: 20,  Continue Verde
# n 8
# Count: 20,  Continue Verde
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Turquesa
# n 7
# Count: 1,  Continue Turquesa
# y 8
# Count: 2,  Continue Turquesa
# n 9
# Count: 2,  Continue Turquesa
# n 10
# Count: 2,  Continue Turquesa
# y 7
# Count: 3,  Continue Turquesa
# y 8
# Count: 4,  Continue Turquesa
# y 9
# Count: 5,  Continue Turquesa
# n 10
# Count: 5,  Continue Turquesa
# n 7
# Count: 5,  Continue Turquesa
# n 8
# Count: 5,  Continue Turquesa
# y 9
# Count: 6,  Continue Turquesa
# n 10
# Count: 6,  Continue Turquesa
# n 7
# Count: 6,  Continue Turquesa
# n 8
# Count: 6,  Continue Turquesa
# y 9
# Count: 7,  Continue Turquesa
# n 10
# Count: 7,  Continue Turquesa
# n 7
# Count: 7,  Continue Turquesa
# n 8
# Count: 7,  Continue Turquesa
# y 9
# Count: 8,  Continue Turquesa
# n 10
# Count: 8,  Continue Turquesa
# n 7
# Count: 8,  Continue Turquesa
# n 8
# Count: 8,  Continue Turquesa
# y 9
# Count: 9,  Continue Turquesa
# n 10
# Count: 9,  Continue Turquesa
# n 7
# Count: 9,  Continue Turquesa
# n 8
# Count: 9,  Continue Turquesa
# y 9
# Count: 10,  Continue Turquesa
# n 10
# Count: 10,  Continue Turquesa
# n 7
# Count: 10,  Continue Turquesa
# n 8
# Count: 10,  Continue Turquesa
# y 9
# Count: 11,  Continue Turquesa
# n 10
# Count: 11,  Continue Turquesa
# n 7
# Count: 11,  Continue Turquesa
# n 8
# Count: 11,  Continue Turquesa
# y 9
# Count: 12,  Continue Turquesa
# n 10
# Count: 12,  Continue Turquesa
# n 7
# Count: 12,  Continue Turquesa
# n 8
# Count: 12,  Continue Turquesa
# y 9
# Count: 13,  Continue Turquesa
# n 10
# Count: 13,  Continue Turquesa
# n 7
# Count: 13,  Continue Turquesa
# n 8
# Count: 13,  Continue Turquesa
# y 9
# Count: 14,  Continue Turquesa
# n 10
# Count: 14,  Continue Turquesa
# n 7
# Count: 14,  Continue Turquesa
# n 8
# Count: 14,  Continue Turquesa
# y 9
# Count: 15,  Continue Turquesa
# n 10
# Count: 15,  Continue Turquesa
# n 7
# Count: 15,  Continue Turquesa
# n 8
# Count: 15,  Continue Turquesa
# y 9
# Count: 16,  Continue Turquesa
# n 10
# Count: 16,  Continue Turquesa
# n 7
# Count: 16,  Continue Turquesa
# n 8
# Count: 16,  Continue Turquesa
# y 9
# Count: 17,  Continue Turquesa
# n 10
# Count: 17,  Continue Turquesa
# n 7
# Count: 17,  Continue Turquesa
# n 8
# Count: 17,  Continue Turquesa
# y 9
# Count: 18,  Continue Turquesa
# n 10
# Count: 18,  Continue Turquesa
# n 7
# Count: 18,  Continue Turquesa
# n 8
# Count: 18,  Continue Turquesa
# y 9
# Count: 19,  Continue Turquesa
# n 10
# Count: 19,  Continue Turquesa
# n 7
# Count: 19,  Continue Turquesa
# n 8
# Count: 19,  Continue Turquesa
# y 9
# Count: 20,  Continue Turquesa
# n 10
# Count: 20,  Continue Turquesa
# n 7
# Count: 20,  Continue Turquesa
# n 8
# Count: 20,  Continue Turquesa
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Azul
# n 7
# Count: 1,  Continue Azul
# y 8
# Count: 2,  Continue Azul
# n 9
# Count: 2,  Continue Azul
# n 10
# Count: 2,  Continue Azul
# y 7
# Count: 3,  Continue Azul
# y 8
# Count: 4,  Continue Azul
# y 9
# Count: 5,  Continue Azul
# n 10
# Count: 5,  Continue Azul
# n 7
# Count: 5,  Continue Azul
# n 8
# Count: 5,  Continue Azul
# y 9
# Count: 6,  Continue Azul
# n 10
# Count: 6,  Continue Azul
# n 7
# Count: 6,  Continue Azul
# n 8
# Count: 6,  Continue Azul
# y 9
# Count: 7,  Continue Azul
# n 10
# Count: 7,  Continue Azul
# n 7
# Count: 7,  Continue Azul
# n 8
# Count: 7,  Continue Azul
# y 9
# Count: 8,  Continue Azul
# n 10
# Count: 8,  Continue Azul
# n 7
# Count: 8,  Continue Azul
# n 8
# Count: 8,  Continue Azul
# y 9
# Count: 9,  Continue Azul
# n 10
# Count: 9,  Continue Azul
# n 7
# Count: 9,  Continue Azul
# n 8
# Count: 9,  Continue Azul
# y 9
# Count: 10,  Continue Azul
# n 10
# Count: 10,  Continue Azul
# n 7
# Count: 10,  Continue Azul
# n 8
# Count: 10,  Continue Azul
# y 9
# Count: 11,  Continue Azul
# n 10
# Count: 11,  Continue Azul
# n 7
# Count: 11,  Continue Azul
# n 8
# Count: 11,  Continue Azul
# y 9
# Count: 12,  Continue Azul
# n 10
# Count: 12,  Continue Azul
# n 7
# Count: 12,  Continue Azul
# n 8
# Count: 12,  Continue Azul
# y 9
# Count: 13,  Continue Azul
# n 10
# Count: 13,  Continue Azul
# n 7
# Count: 13,  Continue Azul
# n 8
# Count: 13,  Continue Azul
# y 9
# Count: 14,  Continue Azul
# n 10
# Count: 14,  Continue Azul
# n 7
# Count: 14,  Continue Azul
# n 8
# Count: 14,  Continue Azul
# y 9
# Count: 15,  Continue Azul
# n 10
# Count: 15,  Continue Azul
# n 7
# Count: 15,  Continue Azul
# n 8
# Count: 15,  Continue Azul
# y 9
# Count: 16,  Continue Azul
# n 10
# Count: 16,  Continue Azul
# n 7
# Count: 16,  Continue Azul
# n 8
# Count: 16,  Continue Azul
# y 9
# Count: 17,  Continue Azul
# n 10
# Count: 17,  Continue Azul
# n 7
# Count: 17,  Continue Azul
# n 8
# Count: 17,  Continue Azul
# y 9
# Count: 18,  Continue Azul
# n 10
# Count: 18,  Continue Azul
# n 7
# Count: 18,  Continue Azul
# n 8
# Count: 18,  Continue Azul
# y 9
# Count: 19,  Continue Azul
# n 10
# Count: 19,  Continue Azul
# n 7
# Count: 19,  Continue Azul
# n 8
# Count: 19,  Continue Azul
# y 9
# Count: 20,  Continue Azul
# n 10
# Count: 20,  Continue Azul
# n 7
# Count: 20,  Continue Azul
# n 8
# Count: 20,  Continue Azul
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Morado
# n 7
# Count: 1,  Continue Morado
# y 8
# Count: 2,  Continue Morado
# n 9
# Count: 2,  Continue Morado
# n 10
# Count: 2,  Continue Morado
# y 7
# Count: 3,  Continue Morado
# y 8
# Count: 4,  Continue Morado
# y 9
# Count: 5,  Continue Morado
# n 10
# Count: 5,  Continue Morado
# n 7
# Count: 5,  Continue Morado
# n 8
# Count: 5,  Continue Morado
# y 9
# Count: 6,  Continue Morado
# n 10
# Count: 6,  Continue Morado
# n 7
# Count: 6,  Continue Morado
# n 8
# Count: 6,  Continue Morado
# y 9
# Count: 7,  Continue Morado
# n 10
# Count: 7,  Continue Morado
# n 7
# Count: 7,  Continue Morado
# n 8
# Count: 7,  Continue Morado
# y 9
# Count: 8,  Continue Morado
# n 10
# Count: 8,  Continue Morado
# n 7
# Count: 8,  Continue Morado
# n 8
# Count: 8,  Continue Morado
# y 9
# Count: 9,  Continue Morado
# n 10
# Count: 9,  Continue Morado
# n 7
# Count: 9,  Continue Morado
# n 8
# Count: 9,  Continue Morado
# y 9
# Count: 10,  Continue Morado
# n 10
# Count: 10,  Continue Morado
# n 7
# Count: 10,  Continue Morado
# n 8
# Count: 10,  Continue Morado
# y 9
# Count: 11,  Continue Morado
# n 10
# Count: 11,  Continue Morado
# n 7
# Count: 11,  Continue Morado
# n 8
# Count: 11,  Continue Morado
# y 9
# Count: 12,  Continue Morado
# n 10
# Count: 12,  Continue Morado
# n 7
# Count: 12,  Continue Morado
# n 8
# Count: 12,  Continue Morado
# y 9
# Count: 13,  Continue Morado
# n 10
# Count: 13,  Continue Morado
# n 7
# Count: 13,  Continue Morado
# n 8
# Count: 13,  Continue Morado
# y 9
# Count: 14,  Continue Morado
# n 10
# Count: 14,  Continue Morado
# n 7
# Count: 14,  Continue Morado
# n 8
# Count: 14,  Continue Morado
# y 9
# Count: 15,  Continue Morado
# n 10
# Count: 15,  Continue Morado
# n 7
# Count: 15,  Continue Morado
# n 8
# Count: 15,  Continue Morado
# y 9
# Count: 16,  Continue Morado
# n 10
# Count: 16,  Continue Morado
# n 7
# Count: 16,  Continue Morado
# n 8
# Count: 16,  Continue Morado
# y 9
# Count: 17,  Continue Morado
# n 10
# Count: 17,  Continue Morado
# n 7
# Count: 17,  Continue Morado
# n 8
# Count: 17,  Continue Morado
# y 9
# Count: 18,  Continue Morado
# n 10
# Count: 18,  Continue Morado
# n 7
# Count: 18,  Continue Morado
# n 8
# Count: 18,  Continue Morado
# y 9
# Count: 19,  Continue Morado
# n 10
# Count: 19,  Continue Morado
# n 7
# Count: 19,  Continue Morado
# n 8
# Count: 19,  Continue Morado
# y 9
# Count: 20,  Continue Morado
# n 10
# Count: 20,  Continue Morado
# n 7
# Count: 20,  Continue Morado
# n 8
# Count: 20,  Continue Morado
# y 9
# Color done
# Count: 21,  Next color
# Start with Color: Dorado
# n 7
# Count: 1,  Continue Dorado
# y 8
# Count: 2,  Continue Dorado
# n 9
# Count: 2,  Continue Dorado
# n 10
# Count: 2,  Continue Dorado
# y 7
# Count: 3,  Continue Dorado
# y 8
# Count: 4,  Continue Dorado
# y 9
# Count: 5,  Continue Dorado
# n 10
# Count: 5,  Continue Dorado
# n 7
# Count: 5,  Continue Dorado
# n 8
# Count: 5,  Continue Dorado
# y 9
# Count: 6,  Continue Dorado
# n 10
# Count: 6,  Continue Dorado
# n 7
# Count: 6,  Continue Dorado
# n 8
# Count: 6,  Continue Dorado
# y 9
# Count: 7,  Continue Dorado
# n 10
# Count: 7,  Continue Dorado
# n 7
# Count: 7,  Continue Dorado
# n 8
# Count: 7,  Continue Dorado
# y 9
# Count: 8,  Continue Dorado
# n 10
# Count: 8,  Continue Dorado
# n 7
# Count: 8,  Continue Dorado
# n 8
# Count: 8,  Continue Dorado
# y 9
# Count: 9,  Continue Dorado
# n 10
# Count: 9,  Continue Dorado
# n 7
# Count: 9,  Continue Dorado
# n 8
# Count: 9,  Continue Dorado
# y 9
# Count: 10,  Continue Dorado
# n 10
# Count: 10,  Continue Dorado
# n 7
# Count: 10,  Continue Dorado
# n 8
# Count: 10,  Continue Dorado
# y 9
# Count: 11,  Continue Dorado
# n 10
# Count: 11,  Continue Dorado
# n 7
# Count: 11,  Continue Dorado
# n 8
# Count: 11,  Continue Dorado
# y 9
# Count: 12,  Continue Dorado
# n 10
# Count: 12,  Continue Dorado
# n 7
# Count: 12,  Continue Dorado
# n 8
# Count: 12,  Continue Dorado
# y 9
# Count: 13,  Continue Dorado
# n 10
# Count: 13,  Continue Dorado
# n 7
# Count: 13,  Continue Dorado
# n 8
# Count: 13,  Continue Dorado
# y 9
# Count: 14,  Continue Dorado
# n 10
# Count: 14,  Continue Dorado
# n 7
# Count: 14,  Continue Dorado
# n 8
# Count: 14,  Continue Dorado
# y 9
# Count: 15,  Continue Dorado
# n 10
# Count: 15,  Continue Dorado
# n 7
# Count: 15,  Continue Dorado
# n 8
# Count: 15,  Continue Dorado
# y 9
# Count: 16,  Continue Dorado
# n 10
# Count: 16,  Continue Dorado
# n 7
# Count: 16,  Continue Dorado
# n 8
# Count: 16,  Continue Dorado
# y 9
# Count: 17,  Continue Dorado
# n 10
# Count: 17,  Continue Dorado
# n 7
# Count: 17,  Continue Dorado
# n 8
# Count: 17,  Continue Dorado
# y 9
# Count: 18,  Continue Dorado
# n 10
# Count: 18,  Continue Dorado
# n 7
# Count: 18,  Continue Dorado
# n 8
# Count: 18,  Continue Dorado
# y 9
# Count: 19,  Continue Dorado
# n 10
# Count: 19,  Continue Dorado
# n 7
# Count: 19,  Continue Dorado
# n 8
# Count: 19,  Continue Dorado
# y 9
# Count: 20,  Continue Dorado
# n 10
# Count: 20,  Continue Dorado
# n 7
# Count: 20,  Continue Dorado
# n 8
# Count: 20,  Continue Dorado
# y 9
# Color done
# Count: 21,  Next color
# All done!!

# %% [markdown]
# ## 3 Save raw data - using pickle
#
# **Don't run it**  to avoid overwritting!

# %% [markdown]
# For women

# %%
#amz1_womentshirt_data=products_pag_dict

#with open('amz1_womentshirt_data.pkl', 'wb') as file:
#    pickle.dump(amz1_womentshirt_data, file)

# %% [markdown]
# For men

# %%
#amz_men_tshirt_data=products_pag_dict

#with open('amz_men_tshirt_data.pkl', 'wb') as file:
#    pickle.dump(amz_men_tshirt_data, file)
